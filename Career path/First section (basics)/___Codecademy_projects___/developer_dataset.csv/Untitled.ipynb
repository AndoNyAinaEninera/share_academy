# %%
import pandas as pd


df = pd.read_csv('developer_dataset.csv', low_memory=False)

# %%
maxRows = df['RespondentID'].count()

print('% Missing Data:')
print((1 - df.count() / maxRows) * 100)
# Out:
# % Missing Data:
# RespondentID               0.000000
# Year                       0.000000
# Country                    0.000000
# Employment                 1.604187
# UndergradMajor            11.470295
# DevType                    9.689863
# LanguageWorkedWith         8.264619
# LanguageDesireNextYear    13.636486
# DatabaseWorkedWith        22.794918
# DatabaseDesireNextYear    33.248208
# PlatformWorkedWith        17.624473
# PlatformDesireNextYear    23.229235
# Hobbyist                  38.537349
# OrgSize                   50.719816
# YearsCodePro              14.761395
# JobSeek                   45.547573
# ConvertedComp             17.872654
# WorkWeekHrs               54.060373
# NEWJobHunt                82.800852
# NEWJobHuntResearch        83.200101
# NEWLearn                  78.215792
# dtype: float64

# %%
df[['Country', 'Employment', 'DevType']].sample(n=20)
# Out:
#                Country                                         Employment  \
# 95502            Spain                                 Employed full-time
# 26652    United States                                 Employed full-time
# 8068     United States                                 Employed full-time
# 81716          Germany                                 Employed full-time
# 43341    United States                                 Employed full-time
# 14269    United States                 Not employed, but looking for work
# 74453   United Kingdom                                            Student
# 76268   United Kingdom                                 Employed full-time
# 27547    United States                                 Employed full-time
# 61612    United States                                 Employed full-time
# 37133    United States                                 Employed part-time
# 66778           Canada                                 Employed part-time
# 99286   United Kingdom                                 Employed full-time
# 92279          Germany                                                NaN
# 43653    United States                                 Employed full-time
# 101762  United Kingdom                                 Employed full-time
# 58182    United States  Independent contractor, freelancer, or self-em...
# 52288    United States                                 Employed full-time
# 55750    United States                                 Employed full-time
# 26320    United States                                 Employed full-time
#
#                                                   DevType
# 95502                               Developer, full-stack
# 26652   Back-end developer;Desktop or enterprise appli...
# 8068                                 Developer, front-end
# 81716   Developer, back-end;Developer, front-end;Devel...
# 43341                                   DevOps specialist
# 14269                         Academic researcher;Student
# 74453                                                 NaN
# 76268                                                 NaN
# 27547          Developer, full-stack;System administrator
# 61612                               Developer, full-stack
# 37133   Database administrator;Developer, back-end;Dev...
# 66778                                             Student
# 99286                               Developer, full-stack
# 92279   Back-end developer;Desktop or enterprise appli...
# 43653                                Full-stack developer
# 101762  Academic researcher;Data scientist or machine ...
# 58182                     Marketing or sales professional
# 52288               Database administrator;Engineer, data
# 55750   Developer, back-end;Developer, full-stack;Deve...
# 26320   Developer, back-end;Developer, front-end;Devel...

# %%
df.loc[df['Employment'] == 'Student', ['Country', 'Employment', 'DevType']]
# Out:
#              Country Employment DevType
# 26     United States    Student     NaN
# 65     United States    Student     NaN
# 71     United States    Student     NaN
# 80     United States    Student     NaN
# 101    United States    Student     NaN
# ...              ...        ...     ...
# 79943          Japan    Student     NaN
# 79952          Japan    Student     NaN
# 80000          Japan    Student     NaN
# 80006          Japan    Student     NaN
# 80123          Japan    Student     NaN
#
# [2789 rows x 3 columns]
